# %% [markdown]
# # Ejercicios - Básico

# %% [markdown]
# 1. Escribir un programa que solicite información básica
# 2. Escribir un script que capture la altura y el peso de una persona y calcule el IMC
#     ![image.png](attachment:image.png)
# 3. Escribir una rutina que lea un número entero positivo (evaluar que así sea), nume; y muestre la suma de los numeros desde el 1 hasta nume. para ello tenga en cuenta que podemos sumar los números positivos hasta un limite usando la sig, formula:  ( n(n + 1) ) / 2
